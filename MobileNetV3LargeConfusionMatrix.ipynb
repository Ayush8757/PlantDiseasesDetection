# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# Load your trained model
model = tf.keras.models.load_model("/content/drive/MyDrive/MobileNetV3Large_village_model.keras")
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 174 variables whereas the saved optimizer has 350 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
# Load the PlantVillage dataset from TFDS
dataset_name = "plant_village"
(ds_train, ds_test), ds_info = tfds.load(
    dataset_name, split=["train[:80%]", "train[80%:]"], as_supervised=True, with_info=True
)
# Out:
# WARNING:absl:Variant folder /root/tensorflow_datasets/plant_village/1.0.2 has no dataset_info.json
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/plant_village/1.0.2...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/1 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/plant_village/incomplete.WJOXCS_1.0.2/plant_village-train.tfrecord*...:   …
# Dataset plant_village downloaded and prepared to /root/tensorflow_datasets/plant_village/1.0.2. Subsequent calls will reuse this data.

# %%
# Get class names
class_names = ds_info.features["label"].names
num_classes = len(class_names)

# %%
# Preprocessing function
def preprocess(image, label):
    image = tf.image.resize(image, (224, 224))   # Resize and normalize
    return image, label

# %%
# Apply preprocessing to test dataset
ds_test = ds_test.map(preprocess).batch(32)  # Batch size of 32

# %%
# Get true labels
y_true = np.concatenate([y.numpy() for _, y in ds_test], axis=0)

# %%
# Predict labels
y_pred_probs = model.predict(ds_test)
y_pred = np.argmax(y_pred_probs, axis=1)  # Convert probabilities to class indices
# Out:
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 45s 93ms/step

# %%
# Compute confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred)

# %%
# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()

# %%
# Compute Precision, Recall, and F1-score
report = classification_report(y_true, y_pred, target_names=class_names)
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                                                 precision    recall  f1-score   support
#
#                            Apple___Apple_scab       1.00      1.00      1.00       129
#                             Apple___Black_rot       1.00      1.00      1.00       154
#                      Apple___Cedar_apple_rust       1.00      1.00      1.00        54
#                               Apple___healthy       1.00      1.00      1.00       339
#                           Blueberry___healthy       1.00      1.00      1.00       292
#                              Cherry___healthy       1.00      1.00      1.00       195
#                       Cherry___Powdery_mildew       1.00      1.00      1.00       201
#    Corn___Cercospora_leaf_spot Gray_leaf_spot       0.99      0.98      0.99       108
#                            Corn___Common_rust       1.00      1.00      1.00       239
#                                Corn___healthy       1.00      1.00      1.00       223
#                   Corn___Northern_Leaf_Blight       0.99      0.99      0.99       197
#                             Grape___Black_rot       1.00      1.00      1.00       224
#                  Grape___Esca_(Black_Measles)       1.00      1.00      1.00       272
#                               Grape___healthy       1.00      1.00      1.00        74
#    Grape___Leaf_blight_(Isariopsis_Leaf_Spot)       1.00      1.00      1.00       195
#      Orange___Haunglongbing_(Citrus_greening)       1.00      1.00      1.00      1108
#                        Peach___Bacterial_spot       1.00      1.00      1.00       459
#                               Peach___healthy       1.00      1.00      1.00        68
#                 Pepper,_bell___Bacterial_spot       1.00      1.00      1.00       197
#                        Pepper,_bell___healthy       1.00      1.00      1.00       304
#                         Potato___Early_blight       1.00      1.00      1.00       208
#                              Potato___healthy       1.00      1.00      1.00        30
#                          Potato___Late_blight       1.00      1.00      1.00       199
#                           Raspberry___healthy       1.00      1.00      1.00        69
#                             Soybean___healthy       1.00      1.00      1.00      1047
#                       Squash___Powdery_mildew       1.00      1.00      1.00       369
#                          Strawberry___healthy       1.00      1.00      1.00       103
#                      Strawberry___Leaf_scorch       1.00      1.00      1.00       186
#                       Tomato___Bacterial_spot       1.00      1.00      1.00       395
#                         Tomato___Early_blight       1.00      1.00      1.00       193
#                              Tomato___healthy       1.00      1.00      1.00       330
#                          Tomato___Late_blight       1.00      1.00      1.00       373
#                            Tomato___Leaf_Mold       1.00      1.00      1.00       194
#                   Tomato___Septoria_leaf_spot       1.00      1.00      1.00       362
# Tomato___Spider_mites Two-spotted_spider_mite       1.00      1.00      1.00       316
#                          Tomato___Target_Spot       1.00      1.00      1.00       280
#                  Tomato___Tomato_mosaic_virus       1.00      1.00      1.00        70
#        Tomato___Tomato_Yellow_Leaf_Curl_Virus       1.00      1.00      1.00      1105
#
#                                      accuracy                           1.00     10861
#                                     macro avg       1.00      1.00      1.00     10861
#                                  weighted avg       1.00      1.00      1.00     10861

# %%
k = model.evaluate(ds_test)
print(k)
# Out:
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 24s 42ms/step - accuracy: 0.9992 - loss: 0.0056
# [0.0023272980470210314, 0.9996317028999329]

# %%
loss, accuracy = model.evaluate(ds_test)
print(f"Test Accuracy: {accuracy * 100:.2f}%")
# Out:
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 13s 39ms/step - accuracy: 0.9992 - loss: 0.0056
# Test Accuracy: 99.96%
